# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error,mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense,Dropout,Bidirectional
import matplotlib.pyplot as plt

df=pd.read_csv("AirPassengers.csv")

data=df[['#Passengers']]

scaler=MinMaxScaler(feature_range=(0,1))

scaled_data=scaler.fit_transform(data)

X=[]
y=[]

for i in range(12,len(scaled_data)):
    X.append(scaled_data[i-12:i,0])
    y.append(scaled_data[i,0])

X=np.array(X)
y=np.array(y)

X=X.reshape(X.shape[0],X.shape[1],1)

split=int(len(X)*0.8)

X_train=X[:split]
X_test=X[split:]
y_train=y[:split]
y_test=y[split:]

model=Sequential([
    Bidirectional(LSTM(64,return_sequences=True),input_shape=(12,1)),
    Dropout(0.2),
    Bidirectional(LSTM(32)),
    Dropout(0.2),
    Dense(16,activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam',loss='mean_squared_error')

history=model.fit(X_train,y_train,epochs=50,batch_size=16,validation_split=0.2)

predictions=model.predict(X_test)

predictions=scaler.inverse_transform(predictions)

actual=scaler.inverse_transform(y_test.reshape(-1,1))

mae=mean_absolute_error(actual,predictions)
mse=mean_squared_error(actual,predictions)
rmse=np.sqrt(mse)

print("MAE:",mae)
print("MSE:",mse)
print("RMSE:",rmse)

plt.figure(figsize=(12,6))
plt.plot(actual,label="Actual Passengers")
plt.plot(predictions,label="Predicted Passengers")
plt.legend()
plt.show()

last_12_months=scaled_data[-12:].flatten().tolist()

future_passengers=[]

for _ in range(7):
    x=np.array(last_12_months[-12:]).reshape(1,12,1)
    pred=model.predict(x,verbose=0)[0][0]
    future_passengers.append(pred)
    last_12_months.append(pred)

future_passengers=scaler.inverse_transform(np.array(future_passengers).reshape(-1,1))

print("\nNext 7 Months Passenger Forecast")

for i,val in enumerate(future_passengers,start=1):
    print(f"Month {i}: {int(val[0])}")

model.save("airpassenger_bilstm.keras")

joblib.dump(scaler,"airpassenger_scaler.pkl")
# Out:
# C:\Users\Raghunandan\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 174ms/step - loss: 0.0226 - val_loss: 0.0156
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0081 - val_loss: 0.0244
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0073 - val_loss: 0.0229
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0054 - val_loss: 0.0136
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0059 - val_loss: 0.0138
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0047 - val_loss: 0.0166
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0050 - val_loss: 0.0132
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0044 - val_loss: 0.0134
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0038 - val_loss: 0.0132
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0046 - val_loss: 0.0131
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0039 - val_loss: 0.0137
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0043 - val_loss: 0.0124
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0040 - val_loss: 0.0123
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0052 - val_loss: 0.0120
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0038 - val_loss: 0.0123
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0039 - val_loss: 0.0117
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0038 - val_loss: 0.0115
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0040 - val_loss: 0.0114
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037 - val_loss: 0.0137
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0042 - val_loss: 0.0111
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0031 - val_loss: 0.0110
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0037 - val_loss: 0.0111
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0046 - val_loss: 0.0108
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0032 - val_loss: 0.0102
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0039 - val_loss: 0.0113
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0033 - val_loss: 0.0103
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0040 - val_loss: 0.0095
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0039 - val_loss: 0.0091
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0038 - val_loss: 0.0097
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0034 - val_loss: 0.0089
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0030 - val_loss: 0.0085
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0030 - val_loss: 0.0084
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0039 - val_loss: 0.0079
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0037 - val_loss: 0.0079
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0028 - val_loss: 0.0077
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0022 - val_loss: 0.0085
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0033 - val_loss: 0.0077
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0027 - val_loss: 0.0069
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0027 - val_loss: 0.0062
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0028 - val_loss: 0.0057
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0023 - val_loss: 0.0061
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0023 - val_loss: 0.0062
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0023 - val_loss: 0.0061
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0019 - val_loss: 0.0053
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0034 - val_loss: 0.0048
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0025 - val_loss: 0.0042
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0021 - val_loss: 0.0058
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0022 - val_loss: 0.0036
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# MAE: 26.940787986472802
# MSE: 1340.6532611562352
# RMSE: 36.614932215644416
# Next 7 Months Passenger Forecast
# Month 1: 418
# Month 2: 421
# Month 3: 451
# Month 4: 491
# Month 5: 530
# Month 6: 578
# Month 7: 602
# ['airpassenger_scaler.pkl']
